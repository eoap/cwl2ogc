# %% [markdown]
# # Exclusive Input Parameters with Expressions
#
# Exclusive Input Parameters with Expressions refers to the [2.4.3.1. Exclusive Input Parameters with Expressions](https://www.commonwl.org/user_guide/topics/inputs.html#exclusive-input-parameters-with-expressions) paragraph of the _2.4. Inputs_ chapter of the [Common Workflow Language User Guide](https://www.commonwl.org/user_guide/index.html#).

# %% [markdown]
# ## 1. Parsing
#
# In this sample we'll show the access from a remote public URL.

# %%
from cwl_loader import load_cwl_from_location
from cwl2ogc import BaseCWLtypes2OGCConverter

cwl_document = load_cwl_from_location('https://raw.githubusercontent.com/eoap/cwl2ogc/refs/heads/develop/tests/artifacts/cwl-types/exclusive-parameter-expressions.cwl')
cwl_converter = BaseCWLtypes2OGCConverter(cwl_document)
# Out:
# 2025-11-06 23:50:13.221 | DEBUG    | cwl_loader:load_cwl_from_location:228 - Loading CWL document from https://raw.githubusercontent.com/eoap/cwl2ogc/refs/heads/develop/tests/artifacts/cwl-types/exclusive-parameter-expressions.cwl...
# 2025-11-06 23:50:13.507 | DEBUG    | cwl_loader:_load_cwl_from_stream:231 - Reading stream from https://raw.githubusercontent.com/eoap/cwl2ogc/refs/heads/develop/tests/artifacts/cwl-types/exclusive-parameter-expressions.cwl...
# 2025-11-06 23:50:13.512 | DEBUG    | cwl_loader:load_cwl_from_stream:203 - CWL data of type <class 'ruamel.yaml.comments.CommentedMap'> successfully loaded from stream
# 2025-11-06 23:50:13.512 | DEBUG    | cwl_loader:load_cwl_from_yaml:143 - No needs to update the Raw CWL document since it targets already the v1.2
# 2025-11-06 23:50:13.512 | DEBUG    | cwl_loader:load_cwl_from_yaml:145 - Parsing the raw CWL document to the CWL Utils DOM...
# 2025-11-06 23:50:13.873 | DEBUG    | cwl_loader:load_cwl_from_yaml:158 - Raw CWL document successfully parsed to the CWL Utils DOM!
# 2025-11-06 23:50:13.874 | DEBUG    | cwl_loader:load_cwl_from_yaml:160 - Dereferencing the steps[].run...
# 2025-11-06 23:50:13.874 | DEBUG    | cwl_loader:load_cwl_from_yaml:167 - steps[].run successfully dereferenced! Dereferencing the FQNs...
# 2025-11-06 23:50:13.875 | DEBUG    | cwl_loader:load_cwl_from_yaml:171 - CWL document successfully dereferenced! Now verifying steps[].run integrity...
# 2025-11-06 23:50:13.875 | DEBUG    | cwl_loader:load_cwl_from_yaml:175 - All steps[].run link are resolvable!
# 2025-11-06 23:50:13.875 | DEBUG    | cwl_loader:load_cwl_from_yaml:178 - Sorting Process instances by dependencies....
# 2025-11-06 23:50:13.875 | DEBUG    | cwl_loader:load_cwl_from_yaml:180 - Sorting process is over.
# 2025-11-06 23:50:13.876 | DEBUG    | cwl_loader:_load_cwl_from_stream:240 - Stream from https://raw.githubusercontent.com/eoap/cwl2ogc/refs/heads/develop/tests/artifacts/cwl-types/exclusive-parameter-expressions.cwl successfully load!

# %% [markdown]
# # 2. Inputs conversion
#
# Once the document is parsed, invoke the `cwl2ogc` APIs to convert the CWL inputs to the OGC JSON format:

# %%
import sys

cwl_converter.dump_inputs(stream=sys.stdout, pretty_print=True)
# Out:
# {
#   "file_format": {
#     "schema": {
#       "nullable": true,
#       "type": "string",
#       "enum": [
#         "auto",
#         "fasta",
#         "fastq",
#         "fasta.gz",
#         "fastq.gz"
#       ]
#     },
#     "metadata": [
#       {
#         "title": "cwl:type",
#         "value": "[ null, enum[ auto, fasta, fastq, fasta.gz, fastq.gz ] ]"
#       }
#     ],
#     "minOccurs": 0,
#     "maxOccurs": 1,
#     "valuePassing": "byValue",
#     "title": "file_format label",
#     "description": "file_format doc"
#   }
# }

# %% [markdown]
# # 3. Outputs conversion
#
# Users can reuse the `BaseCWLtypes2OGCConverter` instance to convert the CWL outputs to the OGC JSON format:

# %%
cwl_converter.dump_outputs(stream=sys.stdout, pretty_print=True)
# Out:
# {
#   "text_output": {
#     "schema": {
#       "type": "string"
#     },
#     "metadata": [
#       {
#         "title": "cwl:type",
#         "value": "string"
#       }
#     ]
#   }
# }
